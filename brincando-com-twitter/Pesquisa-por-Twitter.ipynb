# %%
import twitter
import json
from urllib.parse import unquote

#Credenciais de acesso ao Twitter
CONSUMER_KEY = 'jQcDAPzXorkWPWx7xQLOkm1e9'
CONSUMER_SECRET = 'PBWJMcnpOuW1xDnCBLOFHbeydCNkXLrTpBTuWcLU5uQCGQ36N1'
OAUTH_TOKEN = '2544081954-JxjB2mUdw3PNnzhboqzyq6nFgKPFCWYw4lfPPyq'
OAUTH_TOKEN_SECRET = '71TP3qkhCXtw1c2nnEVJAfRvuy4a078KVBX9c0cQVYIVV'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET, CONSUMER_KEY, CONSUMER_SECRET)
twitter_api = twitter.Twitter(auth=auth)

# %%
q = '#PelaVidaEPorDireitos'

count = 100

search_results = twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']

for _ in range(5):
    print('Tamanho do Status',len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError as e:
        break
        
    kwargs = dict([kv.split('=') for kv in unquote(next_results[1:]).split("&")])
    
    search_results = twitter_api.search.tweets(**kwargs)
    
    statuses += search_results['statuses']

#Mostrar resultados
print(json.dumps(statuses[0],indent=1))
# Out:
# Tamanho do Status 83
# Tamanho do Status 163
# Tamanho do Status 263
# Tamanho do Status 351
# Tamanho do Status 451
# {
#  "created_at": "Fri Mar 08 18:47:18 +0000 2019",
#  "id": 1104091235407618048,
#  "id_str": "1104091235407618048",
#  "text": "#8M2019 #DiaInternacionalDaMulher #PelaVidaEPorDireitos https://t.co/sFywvX264L",
#  "truncated": false,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "8M2019",
#     "indices": [
#      0,
#      7
#     ]
#    },
#    {
#     "text": "DiaInternacionalDaMulher",
#     "indices": [
#      8,
#      33
#     ]
#    },
#    {
#     "text": "PelaVidaEPorDireitos",
#     "indices": [
#      34,
#      55
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [],
#   "urls": [
#    {
#     "url": "https://t.co/sFywvX264L",
#     "expanded_url": "https://twitter.com/agenciapublica/status/1104089852612657153",
#     "display_url": "twitter.com/agenciapublica\u2026",
#     "indices": [
#      56,
#      79
#     ]
#    }
#   ]
#  },
#  "metadata": {
#   "iso_language_code": "und",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 163981592,
#   "id_str": "163981592",
#   "name": "Fl\u00e1via Junqueira",
#   "screen_name": "flaviacjunq",
#   "location": "Rio de Janeiro, Brazil",
#   "description": "Doutoranda em Comunica\u00e7\u00e3o pela UERJ, produtora cultural e assessora de imprensa / Doctoral student, cultural producer and press officer / Rio de Janeiro - Br",
#   "url": null,
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 314,
#   "friends_count": 1095,
#   "listed_count": 5,
#   "created_at": "Wed Jul 07 19:08:59 +0000 2010",
#   "favourites_count": 813,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 700,
#   "lang": "pt",
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "4D91A8",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme13/bg.gif",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme13/bg.gif",
#   "profile_background_tile": true,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/532908890770243585/xyS-Jwc4_normal.jpeg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/532908890770243585/xyS-Jwc4_normal.jpeg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/163981592/1415890493",
#   "profile_link_color": "D9A109",
#   "profile_sidebar_border_color": "D1107E",
#   "profile_sidebar_fill_color": "3E9BAD",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": false,
#   "default_profile": false,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "is_quote_status": true,
#  "quoted_status_id": 1104089852612657153,
#  "quoted_status_id_str": "1104089852612657153",
#  "quoted_status": {
#   "created_at": "Fri Mar 08 18:41:48 +0000 2019",
#   "id": 1104089852612657153,
#   "id_str": "1104089852612657153",
#   "text": "A P\u00fablica preparou uma edi\u00e7\u00e3o especial com algumas das nossas maiores reportagens a respeito de temas que tocam a t\u2026 https://t.co/QQVEgObqbB",
#   "truncated": true,
#   "entities": {
#    "hashtags": [],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": [
#     {
#      "url": "https://t.co/QQVEgObqbB",
#      "expanded_url": "https://twitter.com/i/web/status/1104089852612657153",
#      "display_url": "twitter.com/i/web/status/1\u2026",
#      "indices": [
#       117,
#       140
#      ]
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "und",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 310497473,
#    "id_str": "310497473",
#    "name": "Ag\u00eancia P\u00fablica",
#    "screen_name": "agenciapublica",
#    "location": "S\u00e3o Paulo, Brasil",
#    "description": "Ag\u00eancia de jornalismo investigativo e independente. Siga tamb\u00e9m no Facebook e no Instagram: @agenciapublica",
#    "url": "http://t.co/Hs5Tk8sy9Q",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/Hs5Tk8sy9Q",
#        "expanded_url": "http://apublica.org",
#        "display_url": "apublica.org",
#        "indices": [
#         0,
#         22
#        ]
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 142858,
#    "friends_count": 692,
#    "listed_count": 1094,
#    "created_at": "Fri Jun 03 21:13:55 +0000 2011",
#    "favourites_count": 2821,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": true,
#    "verified": true,
#    "statuses_count": 16158,
#    "lang": "pt",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "231F20",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/952893740322099206/aQCmgfGm_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/952893740322099206/aQCmgfGm_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/310497473/1516041245",
#    "profile_link_color": "FF691F",
#    "profile_sidebar_border_color": "FFFFFF",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": false,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 2,
#   "favorite_count": 6,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "pt"
#  },
#  "retweet_count": 0,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "possibly_sensitive": false,
#  "lang": "und"
# }
